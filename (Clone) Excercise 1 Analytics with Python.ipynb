# %%
student_name = "Amara"
age          = 19
subject      = "Math"
score        = 72
passed       = True

# %%
type('student_name')

# %%
type('age')

# %%
type('score')

# %%
type('passed')

# %%
student_name = "Amara"
age          = 19
subject      = "Math"
score        = 72
passed       = True

# %%
type(score)

# %%
type(passed)

# %%
score = 72
sum = 72/100*150
print(sum)

# %%
type(sum)

# %%
student_names = "Amara", "Ben", "Chloe", "David", "Eva", "Farai", "Grace","Hassan"
print(student_names)

# %%
student_names[0]

# %%
student_names[-1]

# %%
student_names[2:5]

# %%
len(student_names)

# %%
scores = [72,55,88,45,91,63,50,77]

# %%
print('score:', scores)

# %%
scores[0]

# %%
scores[4]

# %%
scores[0]+scores[0]

# %%
hassan = {
    "student_name": "Hassan",
    "age": 21,
    "subject": "science",
    "score": 77,
    "passed": True 
}

# %%
hassan["subject"]

# %%
hassan["score"] + 10

# %%
type(hassan["passed"])

# %%
students = [
    {'student_name':'amara', 'age':19, 'subject':'math', 'score':72, 'passed':True},    {'student_name':'ben', 'age':21, 'subject':'science', 'score':55, 'passed':False},
    {'student_name':'chloe', 'age':20, 'subject':'math', 'score':88, 'passed':True},
    {'student_name':'david', 'age':22, 'subject':'english', 'score':45, 'passed':False},
]

# %%
students[1]["score"]

# %%
students[0]["student_name"]

# %%
print(len(students))

# %%
student_name = "Amara"
age          = 19
subject      = "Math"
score        = 72
passed       = True

# %%
print(score>60)
print(age==20)
print(subject!= "Science" )
print(score>= 72 )

# %%
print(bool(score > 60 and passed == True)) 
print(bool(age < 18 or score > 70)) 
print(bool(not passed)) 
print(bool(score > 80 and "subject" == "Math"))

# %%
 
score = 72
if score >= 75:
    print('Distinction')
elif score >=50:
    print('pass')
else:
    print('fail')

# %%
score = 45
if score >= 75:
    print('Distinction')
elif score >=50:
    print('pass')
else:
    print('fail')

# %%
score = 91
if score >= 75:
    print('Distinction')
elif score >=50:
    print('pass')
else:
    print('fail')

# %%
#amara
score = 72
subject = 'Math'

if score >= 70 and subject == 'Math':
    print('Math high achiever')
else:
    print('Does not meet criteria')

# %%
#Ben
score = 55
subject = 'science'

if score >= 70 and subject == 'Math':
    print('Math high achiever')
else:
    print('Does not meet criteria')
